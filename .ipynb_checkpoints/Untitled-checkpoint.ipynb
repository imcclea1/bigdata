# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
import re
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud,STOPWORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.feature_extraction.text import CountVectorizer


train = pd.read_csv('train.tsv',sep='\t')
testD = pd.read_csv('test.tsv', sep='\t')

print(train.shape)
print(testD.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-865df315c7a0> in <module>()
#       3 import matplotlib.pyplot as plt
#       4 from nltk.stem import WordNetLemmatizer
# ----> 5 nltk.download('wordnet')
#       6 import re
#       7 import nltk
#
# NameError: name 'nltk' is not defined

# %%
Sentiment_words=[]
for row in train['Sentiment']:
    if row ==0:
        Sentiment_words.append('negative')
    elif row == 1:
        Sentiment_words.append('neutral')
    elif row == 2:
        Sentiment_words.append('somewhat negative')
    elif row == 3:
        Sentiment_words.append('somewhat positive')
    elif row == 4:
        Sentiment_words.append('positive')
    else:
        Sentiment_words.append('Failed')
train['Sentiment_words'] = Sentiment_words

# %%
word_count=pd.value_counts(train['Sentiment_words'].values, sort=False)

# %%
Index = [1,2,3,4,5]
plt.figure(figsize=(15,5))
plt.bar(Index,word_count,color = 'blue')
plt.xticks(Index,['negative','neutral','somewhat negative','somewhat positive','positive'],rotation=45)
plt.ylabel('Word Count')
plt.xlabel('Reaction')
plt.title('Graph of Reactions')
plt.bar(Index, word_count)
for a,b in zip(Index, word_count):
    plt.text(a, b, str(b) ,color='red', fontweight='bold')

# %%
def clean_phrase(phrase): 
    review =phrase
    review = re.sub('[^a-zA-Z]', ' ',review)
    review = review.lower()
    review = review.split()
    lemmatizer = WordNetLemmatizer()
    review = [lemmatizer.lemmatize(w) for w in review if not w in set(stopwords.words('english'))]
    return (' '.join(review))

# %%
clean_words= []
for i in range(0, 156060):
    clean_words.append(clean_phrase(train['Phrase'][i]))

# %%
clean_words1= []
for i in range(0, 156060):
    clean_words1.append(clean_phrase(train['Phrase'][i]))

# %%
print(train)
train['clean_Phrases'] = clean_words
# Out:
#         PhraseId  SentenceId  \
# 0              1           1
# 1              2           1
# 2              3           1
# 3              4           1
# 4              5           1
# 5              6           1
# 6              7           1
# 7              8           1
# 8              9           1
# 9             10           1
# 10            11           1
# 11            12           1
# 12            13           1
# 13            14           1
# 14            15           1
# 15            16           1
# 16            17           1
# 17            18           1
# 18            19           1
# 19            20           1
# 20            21           1
# 21            22           1
# 22            23           1
# 23            24           1
# 24            25           1
# 25            26           1
# 26            27           1
# 27            28           1
# 28            29           1
# 29            30           1
# ...          ...         ...
# 156030    156031        8542
# 156031    156032        8543
# 156032    156033        8543
# 156033    156034        8543
# 156034    156035        8543
# 156035    156036        8543
# 156036    156037        8543
# 156037    156038        8543
# 156038    156039        8543
# 156039    156040        8544
# 156040    156041        8544
# 156041    156042        8544
# 156042    156043        8544
# 156043    156044        8544
# 156044    156045        8544
# 156045    156046        8544
# 156046    156047        8544
# 156047    156048        8544
# 156048    156049        8544
# 156049    156050        8544
# 156050    156051        8544
# 156051    156052        8544
# 156052    156053        8544
# 156053    156054        8544
# 156054    156055        8544
# 156055    156056        8544
# 156056    156057        8544
# 156057    156058        8544
# 156058    156059        8544
# 156059    156060        8544
#
#                                                    Phrase  Sentiment  \
# 0       A series of escapades demonstrating the adage ...          1
# 1       A series of escapades demonstrating the adage ...          2
# 2                                                A series          2
# 3                                                       A          2
# 4                                                  series          2
# 5       of escapades demonstrating the adage that what...          2
# 6                                                      of          2
# 7       escapades demonstrating the adage that what is...          2
# 8                                               escapades          2
# 9       demonstrating the adage that what is good for ...          2
# 10                                demonstrating the adage          2
# 11                                          demonstrating          2
# 12                                              the adage          2
# 13                                                    the          2
# 14                                                  adage          2
# 15                        that what is good for the goose          2
# 16                                                   that          2
# 17                             what is good for the goose          2
# 18                                                   what          2
# 19                                  is good for the goose          2
# 20                                                     is          2
# 21                                     good for the goose          3
# 22                                                   good          3
# 23                                          for the goose          2
# 24                                                    for          2
# 25                                              the goose          2
# 26                                                  goose          2
# 27      is also good for the gander , some of which oc...          2
# 28      is also good for the gander , some of which oc...          2
# 29                                                is also          2
# ...                                                   ...        ...
# 156030                        a joke in the United States          2
# 156031  The movie 's downfall is to substitute plot fo...          1
# 156032                              The movie 's downfall          1
# 156033            is to substitute plot for personality .          1
# 156034              is to substitute plot for personality          1
# 156035                 to substitute plot for personality          2
# 156036                    substitute plot for personality          1
# 156037                                    substitute plot          2
# 156038                                    for personality          2
# 156039  The film is darkly atmospheric , with Herrmann...          2
# 156040  is darkly atmospheric , with Herrmann quietly ...          2
# 156041  is darkly atmospheric , with Herrmann quietly ...          2
# 156042                            is darkly atmospheric ,          2
# 156043                              is darkly atmospheric          3
# 156044  with Herrmann quietly suggesting the sadness a...          2
# 156045  Herrmann quietly suggesting the sadness and ob...          2
# 156046                                           Herrmann          2
# 156047  quietly suggesting the sadness and obsession b...          1
# 156048  suggesting the sadness and obsession beneath H...          2
# 156049               suggesting the sadness and obsession          2
# 156050                          the sadness and obsession          2
# 156051                              sadness and obsession          1
# 156052                                        sadness and          1
# 156053        beneath Hearst 's forced avuncular chortles          2
# 156054                Hearst 's forced avuncular chortles          2
# 156055                                          Hearst 's          2
# 156056                          forced avuncular chortles          1
# 156057                                 avuncular chortles          3
# 156058                                          avuncular          2
# 156059                                           chortles          2
#
#           Sentiment_words
# 0                 neutral
# 1       somewhat negative
# 2       somewhat negative
# 3       somewhat negative
# 4       somewhat negative
# 5       somewhat negative
# 6       somewhat negative
# 7       somewhat negative
# 8       somewhat negative
# 9       somewhat negative
# 10      somewhat negative
# 11      somewhat negative
# 12      somewhat negative
# 13      somewhat negative
# 14      somewhat negative
# 15      somewhat negative
# 16      somewhat negative
# 17      somewhat negative
# 18      somewhat negative
# 19      somewhat negative
# 20      somewhat negative
# 21      somewhat positive
# 22      somewhat positive
# 23      somewhat negative
# 24      somewhat negative
# 25      somewhat negative
# 26      somewhat negative
# 27      somewhat negative
# 28      somewhat negative
# 29      somewhat negative
# ...                   ...
# 156030  somewhat negative
# 156031            neutral
# 156032            neutral
# 156033            neutral
# 156034            neutral
# 156035  somewhat negative
# 156036            neutral
# 156037  somewhat negative
# 156038  somewhat negative
# 156039  somewhat negative
# 156040  somewhat negative
# 156041  somewhat negative
# 156042  somewhat negative
# 156043  somewhat positive
# 156044  somewhat negative
# 156045  somewhat negative
# 156046  somewhat negative
# 156047            neutral
# 156048  somewhat negative
# 156049  somewhat negative
# 156050  somewhat negative
# 156051            neutral
# 156052            neutral
# 156053  somewhat negative
# 156054  somewhat negative
# 156055  somewhat negative
# 156056            neutral
# 156057  somewhat positive
# 156058  somewhat negative
# 156059  somewhat negative
#
# [156060 rows x 5 columns]

# %%
train.drop(['Phrase'],axis=1,inplace=True)

# %%
train.head()
# Out:
#    PhraseId  SentenceId  Sentiment    Sentiment_words  \
# 0         1           1          1            neutral
# 1         2           1          2  somewhat negative
# 2         3           1          2  somewhat negative
# 3         4           1          2  somewhat negative
# 4         5           1          2  somewhat negative
#
#                                        clean_Phrases
# 0  series escapade demonstrating adage good goose...
# 1     series escapade demonstrating adage good goose
# 2                                             series
# 3
# 4                                             series

# %%
def print_wordCloud(reaction, color):
    reaction_words =train[train['Sentiment_words']==(reaction)]
    words = ' '.join(reaction_words['clean_Phrases'])
    split_word = " ".join([word for word in words.split()])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=3000,
                      height=2500
                     ).generate(split_word)
    
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
print_wordCloud('positive', '#7073FF')
print_wordCloud('negative','#777676')
print_wordCloud('somewhat negative', '#1D70B8')
print_wordCloud('somewhat positive', '#F1BD70')
print_wordCloud('neutral', '#BCF4F4')

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
x__train = cv.fit_transform(clean_words).toarray()
x__test= cv.fit_transform(clean_words1).toarray()
#x__test= cv.fit_transform(corpus1).toarray()
y = train.iloc[:, 2].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8b7560b43b98> in <module>()
#       1 from sklearn.feature_extraction.text import CountVectorizer
#       2 cv = CountVectorizer(max_features = 1500)
# ----> 3 x__train = cv.fit_transform(clean_words).toarray()
#       4 x__test= cv.fit_transform(clean_words1).toarray()
#       5 #x__test= cv.fit_transform(corpus1).toarray()
#
# NameError: name 'clean_words' is not defined

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x__train, y, test_size = 0.40, random_state = 0)

from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)
y_real_pred = classifier.predict(x__test)
# Out:
# /Users/nicolekhorosh/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b9d09334f623> in <module>()
#       1 from sklearn.cross_validation import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(x__train, y, test_size = 0.40, random_state = 0)
#       3
#       4 from sklearn.naive_bayes import MultinomialNB
#       5 classifier = MultinomialNB()
#
# NameError: name 'x__train' is not defined

# %%
mse = ((y_pred - y_test) ** 2).mean()
print(mse)
# Out:
# 0.6473792131231577
